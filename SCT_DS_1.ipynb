# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
ds=pd.read_csv("countries-table.csv")

# %%
ds
# Out:
#               country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR        NaN
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK        NaN
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL        NaN
# 233      Vatican City   234        0.44        0.44   VA  VAT        NaN
#
#      growthRate  worldPercentage    density  densityMi  place    pop1980  \
# ...

# %%
ds.shape
# Out:
# (234, 19)

# %%
ds.columns
# Out:
# Index(['country', 'rank', 'area', 'landAreaKm', 'cca2', 'cca3', 'netChange',
#        'growthRate', 'worldPercentage', 'density', 'densityMi', 'place',
#        'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030',
#        'pop2050'],
#       dtype='object')

# %%
ds.info
# Out:
# <bound method DataFrame.info of               country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR        NaN
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK        NaN
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL        NaN
# 233      Vatican City   234        0.44        0.44   VA  VAT        NaN
#
# ...

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of               country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR        NaN
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK        NaN
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL        NaN
# 233      Vatican City   234        0.44        0.44   VA  VAT        NaN
#
# ...

# %%
top_10countries=ds.sort_values(by='pop2023',ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='pop2023',y='country',data=top_10countries,palette='plasma')
plt.title('top 10 countries by 2023 population')
plt.xlabel('population(in billions)')
plt.ylabel('countries')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12024\566605984.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pop2023',y='country',data=top_10countries,palette='plasma')

# %%
print(ds.columns)
# Out:
# Index(['country', 'rank', 'area', 'landAreaKm', 'cca2', 'cca3', 'netChange',
#        'growthRate', 'worldPercentage', 'density', 'densityMi', 'place',
#        'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030',
#        'pop2050'],
#       dtype='object')

# %%
country_data=ds[ds['country']=='India']
years=['pop1980','pop2000','pop2010','pop2022','pop2023','pop2030','pop2050']
population=country_data[years].values.flatten()
plt.figure(figsize=(10,6))
plt.plot(years,population,marker='o',color='green')
plt.title('population growth in India')
plt.xlabel('year')
plt.ylabel('population in billions')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(ds['growthRate'],bins=15,kde=True,color='Blue')
plt.title('distribution of population growth rate')
plt.xlabel('growth rate(%)')
plt.ylabel('frequency')
plt.show()

# %%
top5_countries=ds.sort_values(by='worldPercentage',ascending=False).head(5)
plt.figure(figsize=(10,10))
plt.pie(top5_countries['worldPercentage'],labels=top5_countries['country'],autopct='%1.1f%%',startangle=140,colors=sns.color_palette('pastel'))
plt.title('world population share by top5 countries')
plt.show()
